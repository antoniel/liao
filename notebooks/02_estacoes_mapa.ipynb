# %% [markdown]
# # Estações INMET — Bahia
# Mapa das estações automáticas do INMET presentes no dataset.

# %%
import sys; sys.path.insert(0, '../src')
from hackathon.io import load_estacoes, OUTPUTS
from hackathon.viz import mapa_estacoes

df = load_estacoes()
df.head()

# %%
m = mapa_estacoes(df)
m.save(str(OUTPUTS / 'mapa_estacoes.html'))
m

# %%
df.situacao.value_counts()
